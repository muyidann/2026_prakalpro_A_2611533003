# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“STRUKTUR PERCABANGAN PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **M. Yiwanu Marhudan**
#
# **2611533003**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa karena atas rahmat dan karunia-Nya, laporan praktikum yang berjudul “Struktur Percabangan pada Python” ini dapat diselesaikan dengan baik.
#
# Laporan ini disusun sebagai salah satu bentuk dokumentasi kegiatan praktikum Algoritma dan Pemrograman. Praktikum ini membahas mengenai struktur percabangan pada bahasa pemrograman Python, yang digunakan untuk mengatur jalannya program berdasarkan kondisi tertentu. Materi yang dibahas meliputi penggunaan if, if-else, if-elif-else, multi-if, operator logika, serta match-case.
#
# Melalui praktikum ini, diharapkan dapat meningkatkan pemahaman mengenai cara kerja struktur percabangan serta penerapannya dalam menyelesaikan permasalahan sederhana menggunakan Python. Selain itu, kegiatan praktikum juga memberikan pengalaman dalam membuat program, menjalankan program, mengamati hasil eksekusi, serta menganalisis logika yang digunakan dalam program.
#
# Penulis menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan untuk meningkatkan kualitas laporan maupun pemahaman penulis dalam mempelajari pemrograman.
#
# Semoga laporan ini dapat memberikan manfaat bagi penulis maupun pembaca dalam memahami konsep struktur percabangan pada Python.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Algoritma dan pemrograman merupakan salah satu dasar penting dalam bidang ilmu komputer. Dalam pembuatan sebuah program, diperlukan suatu logika agar program dapat menjalankan perintah sesuai dengan kondisi yang dihadapi. Salah satu konsep dasar yang digunakan untuk mengatur alur program tersebut adalah struktur percabangan.
#
# Struktur percabangan memungkinkan sebuah program untuk memilih tindakan yang berbeda berdasarkan kondisi tertentu. Dengan adanya percabangan, program tidak hanya menjalankan perintah secara berurutan, tetapi dapat menentukan perintah yang harus dijalankan berdasarkan hasil evaluasi suatu kondisi.
#
# Python menyediakan beberapa bentuk struktur percabangan yang dapat digunakan sesuai dengan kebutuhan program. Bentuk dasar yang umum digunakan adalah if, if-else, dan if-elif-else. Selain itu, Python juga menyediakan match-case yang dapat digunakan untuk melakukan pemilihan berdasarkan nilai tertentu. Operator logika seperti and, or, dan != juga dapat digunakan untuk membuat kondisi yang lebih kompleks.
#
# Dalam praktikum ini, struktur percabangan diterapkan melalui beberapa contoh program sederhana. Selain mempelajari bentuk dasar percabangan, praktikum juga membahas penggunaan multi-if untuk mengevaluasi beberapa kondisi secara terpisah. Penerapan konsep tersebut kemudian digunakan dalam sebuah studi kasus berupa sistem loket wahana yang melakukan pemilihan paket, validasi pengunjung, perhitungan diskon, dan evaluasi transaksi.
#
# Oleh karena itu, pemahaman mengenai struktur percabangan sangat diperlukan agar dapat membuat program yang mampu mengambil keputusan berdasarkan kondisi secara tepat dan terstruktur.
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar struktur percabangan dalam bahasa pemrograman Python.
# 2. Mengetahui penggunaan struktur if dalam membuat keputusan berdasarkan suatu kondisi.
# 3. Memahami penggunaan if-else untuk menentukan dua kemungkinan alur program.
# 4. Memahami penggunaan if-elif-else untuk menangani beberapa kondisi.
# 5. Memahami penggunaan operator logika seperti and, or, dan != dalam percabangan.
# 6. Memahami penggunaan multi-if untuk mengevaluasi beberapa kondisi secara terpisah.
# 7. Memahami penggunaan match-case sebagai salah satu bentuk pemilihan kondisi berdasarkan nilai.
# 8. Mampu menerapkan struktur percabangan dalam penyelesaian permasalahan menggunakan Python.
# 9. Mampu menganalisis alur logika dan hasil keluaran dari program yang menggunakan struktur percabangan.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai konsep struktur percabangan pada Python.
# 2. Melatih kemampuan berpikir logis dan sistematis dalam menyelesaikan suatu permasalahan.
# 3. Meningkatkan kemampuan dalam membuat program yang dapat mengambil keputusan berdasarkan kondisi tertentu.
# 4. Mengetahui perbedaan penggunaan if, if-else, if-elif-else, multi-if, dan match-case.
# 5. Melatih kemampuan menggunakan operator logika dalam pembuatan kondisi program.
# 6. Meningkatkan kemampuan membaca, menjalankan, dan menganalisis kode program Python.
# 7. Memberikan pengalaman dalam menerapkan struktur percabangan pada studi kasus yang lebih kompleks.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# #### 2.1.1 Struktur Percabangan
#
# Struktur percabangan merupakan salah satu konsep dasar dalam pemrograman yang digunakan untuk membuat program mengambil keputusan berdasarkan kondisi tertentu. Dengan percabangan, program dapat menjalankan perintah yang berbeda sesuai dengan keadaan atau nilai yang diberikan oleh pengguna. Dalam Python, struktur percabangan yang umum digunakan antara lain `if`, `if-else`, `if-elif-else`, multi-if, dan `match-case`.
#
# #### 2.1.2 Pernyataan if
#
# Pernyataan `if` digunakan untuk menjalankan suatu perintah apabila kondisi yang diberikan bernilai benar (`True`). Jika kondisi bernilai salah (`False`), perintah di dalam `if` tidak akan dijalankan dan program akan melanjutkan ke perintah berikutnya.
#
# Bentuk umum penggunaan `if` adalah:
#
# `if kondisi:`
#
# `    perintah`
#
# Pada contoh program IPK, `if` digunakan untuk memeriksa apakah nilai IPK memenuhi batas yang telah ditentukan. Struktur ini cocok digunakan ketika hanya terdapat satu kondisi yang perlu diperiksa.
#
# #### 2.1.3 Pernyataan if-else
#
# Pernyataan `if-else` digunakan ketika terdapat dua kemungkinan hasil. Jika kondisi pada `if` bernilai benar, perintah pada bagian `if` akan dijalankan. Sebaliknya, jika kondisi bernilai salah, perintah pada bagian `else` akan dijalankan.
#
# Bentuk umum:
#
# `if kondisi:`
#
# `    perintah jika benar`
#
# `else:`
#
# `    perintah jika salah`
#
# Pada contoh program IPK, `if-else` digunakan untuk menentukan apakah pengguna lulus atau tidak berdasarkan nilai IPK.
#
# #### 2.1.4 Pernyataan if-elif-else
#
# Pernyataan `if-elif-else` digunakan ketika program memiliki lebih dari dua kondisi yang harus diperiksa. Program akan memeriksa kondisi secara berurutan mulai dari `if`, kemudian `elif`, dan terakhir `else`. Ketika menemukan kondisi yang bernilai benar, perintah pada kondisi tersebut dijalankan dan kondisi berikutnya tidak diperiksa.
#
# Bentuk umum:
#
# `if kondisi_1:`
#
# `    perintah_1`
#
# `elif kondisi_2:`
#
# `    perintah_2`
#
# `else:`
#
# `    perintah_3`
#
# Pada program pemeriksaan umur dan SIM C, struktur ini digunakan untuk menentukan apakah pengguna boleh membawa motor berdasarkan umur dan kepemilikan SIM. Struktur yang sama juga digunakan pada program konversi nilai angka menjadi nilai huruf.
#
# #### 2.1.5 Multi-If
#
# Multi-if adalah penggunaan beberapa pernyataan `if` secara terpisah dalam satu program. Berbeda dengan `if-elif-else`, setiap kondisi pada multi-if diperiksa secara independen. Artinya, lebih dari satu kondisi dapat bernilai benar dan semua perintah dari kondisi yang terpenuhi dapat dijalankan.
#
# Multi-if dapat digunakan ketika beberapa kondisi dapat berlaku secara bersamaan. Contohnya terdapat pada program perhitungan diskon, yaitu diskon belanja besar, diskon member, dan diskon kode promo dapat diperoleh secara bersamaan. Setiap diskon diperiksa menggunakan `if` yang terpisah sehingga persentase diskon dapat diakumulasikan.
#
# #### 2.1.6 Operator Perbandingan dan Operator Logika
#
# Operator perbandingan digunakan untuk membandingkan dua nilai dan menghasilkan nilai `True` atau `False`. Beberapa operator yang digunakan pada program antara lain:
#
# * `>` digunakan untuk memeriksa apakah suatu nilai lebih besar dari nilai lainnya.
# * `>=` digunakan untuk memeriksa apakah suatu nilai lebih besar atau sama dengan nilai lainnya.
# * `<` digunakan untuk memeriksa apakah suatu nilai lebih kecil dari nilai lainnya.
# * `!=` digunakan untuk memeriksa apakah dua nilai tidak sama.
# * `==` digunakan untuk memeriksa apakah dua nilai sama.
#
# Selain operator perbandingan, terdapat operator logika yang digunakan untuk menggabungkan beberapa kondisi. Salah satunya adalah `and`, yang menghasilkan `True` jika seluruh kondisi yang digabungkan bernilai benar.
#
# Contohnya pada pemeriksaan umur dan SIM C:
#
# `umur_3003 >= 17 and sim_3003 == 'y'`
#
# Kondisi tersebut hanya bernilai benar apabila umur pengguna minimal 17 tahun dan pengguna memiliki SIM C.
#
# #### 2.1.7 Input dan Konversi Tipe Data
#
# Fungsi `input()` digunakan untuk menerima data yang dimasukkan oleh pengguna melalui keyboard. Secara default, hasil dari `input()` berupa data bertipe string.
#
# Untuk mendapatkan tipe data tertentu, input dapat dikonversi menggunakan fungsi seperti `int()` dan `float()`. Fungsi `int()` digunakan untuk mengubah data menjadi bilangan bulat, sedangkan `float()` digunakan untuk mengubah data menjadi bilangan desimal.
#
# Contohnya:
#
# `umur_3003 = int(input("Input umur anda: "))`
#
# Pada kode tersebut, input umur diubah menjadi tipe data integer agar dapat digunakan dalam operasi perbandingan.
#
# #### 2.1.8 Penggunaan strip(), lower(), dan [0]
#
# Metode `.strip()` digunakan untuk menghapus spasi yang terdapat di awal atau akhir teks. Metode `.lower()` digunakan untuk mengubah seluruh huruf dalam teks menjadi huruf kecil. Kedua metode tersebut dapat digunakan untuk membuat input pengguna lebih mudah dibandingkan dengan kondisi yang telah ditentukan.
#
# Contohnya:
#
# `input_member_3003 = input("Apakah Anda member? (y/t): ").strip().lower()`
#
# Selain itu, `[0]` dapat digunakan untuk mengambil karakter pertama dari sebuah string. Pada program pemeriksaan SIM C, `[0]` digunakan untuk mengambil karakter pertama dari jawaban pengguna, misalnya `y` atau `t`.
#
# #### 2.1.9 Operator in
#
# Operator `in` digunakan untuk memeriksa apakah suatu nilai terdapat di dalam sebuah kumpulan data, seperti list. Operator ini menghasilkan nilai `True` jika nilai ditemukan dan `False` jika tidak ditemukan.
#
# Contohnya:
#
# `input_member_3003 in ["y", "ya"]`
#
# Kondisi tersebut digunakan untuk memeriksa apakah pengguna memasukkan jawaban `y` atau `ya`.
#
# #### 2.1.10 match-case
#
# `match-case` merupakan struktur percabangan pada Python yang digunakan untuk mencocokkan suatu nilai dengan beberapa pola atau pilihan yang tersedia. Struktur ini dapat digunakan sebagai alternatif ketika terdapat banyak pilihan yang berbeda.
#
# Bentuk umum:
#
# `match variabel:`
#
# `    case nilai_1:`
#
# `        perintah`
#
# `    case nilai_2:`
#
# `        perintah`
#
# `    case _:`
#
# `        perintah_default`
#
# Pada program konversi angka menjadi nama bulan, `match-case` digunakan untuk mencocokkan angka 1 sampai 12 dengan nama bulan yang sesuai. `case _` digunakan sebagai kondisi default untuk menangani angka yang tidak sesuai dengan pilihan yang tersedia.
#
# #### 2.1.11 Operasi Perhitungan Diskon
#
# Dalam program perhitungan diskon, operator aritmatika digunakan untuk menghitung nominal diskon dan total pembayaran. Persentase diskon diubah terlebih dahulu menjadi bentuk desimal dengan membaginya dengan 100.
#
# Rumus yang digunakan adalah:
#
# Nominal Diskon = Total Belanja × (Total Diskon / 100)
#
# Total Bayar = Total Belanja - Nominal Diskon
#
# Pada program multi-if, beberapa persentase diskon dapat dijumlahkan terlebih dahulu apabila pengguna memenuhi beberapa syarat diskon.
#
# #### 2.1.12 Konversi Nilai Angka Menjadi Nilai Huruf
#
# Struktur `if-elif-else` dapat digunakan untuk mengelompokkan nilai angka ke dalam kategori tertentu. Pada program yang dibuat, nilai angka dikonversi menjadi nilai huruf berdasarkan rentang nilai.
#
# Nilai 81 atau lebih dikategorikan sebagai A, nilai 70 sampai 80 sebagai B, nilai 60 sampai 69 sebagai C, nilai 50 sampai 59 sebagai D, dan nilai di bawah 50 sebagai E.
#
# Penggunaan kondisi secara berurutan memungkinkan program menentukan satu kategori yang sesuai dengan nilai yang dimasukkan pengguna.
#
# #### 2.1.13 Kesimpulan Dasar Teori
#
# Berdasarkan teori tersebut, struktur percabangan merupakan bagian penting dalam pemrograman karena memungkinkan program mengambil keputusan berdasarkan kondisi tertentu. `if` digunakan untuk satu kondisi, `if-else` digunakan untuk dua kemungkinan, sedangkan `if-elif-else` digunakan untuk beberapa kondisi yang saling berurutan. Multi-if digunakan ketika beberapa kondisi perlu diperiksa secara independen dan dapat berlaku secara bersamaan. Sementara itu, `match-case` digunakan untuk mencocokkan suatu nilai dengan beberapa pilihan yang tersedia.
#
# Penggunaan operator perbandingan, operator logika, fungsi `input()`, serta konversi tipe data mendukung proses pengambilan keputusan dalam program. Konsep-konsep tersebut dapat diterapkan pada berbagai permasalahan seperti pemeriksaan kelayakan, penentuan nilai, perhitungan diskon, dan konversi angka menjadi nama bulan.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "if1_2611533003"

# %%
ipk_3003 = float(input("Input IPK Anda: "))

if ipk_3003 >= 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_3003))

print("Program selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 3.2
# Program selesai

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 berfungsi untuk meminta pengguna memasukkan nilai IPK. Fungsi `float()` digunakan untuk mengubah input menjadi tipe data desimal dan hasilnya disimpan dalam variabel `ipk_3003`.
#
# 2. Baris 3 berfungsi untuk melakukan percabangan menggunakan `if`. Kondisi `ipk_3003 >= 2.75` digunakan untuk memeriksa apakah nilai IPK pengguna lebih besar atau sama dengan 2,75.
#
# 3. Baris 4 berfungsi untuk menampilkan pesan bahwa pengguna lulus sangat memuaskan apabila kondisi pada `if` terpenuhi. Fungsi `str()` digunakan untuk mengubah nilai IPK menjadi teks agar dapat digabungkan dengan string menggunakan operator `+`.
#
# 4. Baris 6 berfungsi untuk menampilkan pesan bahwa program telah selesai dijalankan. Baris ini tetap dijalankan meskipun kondisi pada `if` tidak terpenuhi karena tidak berada di dalam blok `if`.

# %% [markdown]
# ### 2.2.2 Program "if2_2611533003"

# %%
ipk_3003 = float(input("Input IPK Anda: "))

if ipk_3003 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_3003))
else:
    print("Anda Tidak Lulus")
print("Program selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 3.2
# Program selesai

# %% [markdown]
# **Penjelasan :**
# 1. **Baris 1** berfungsi untuk meminta pengguna memasukkan nilai IPK. Fungsi `float()` digunakan untuk mengubah input menjadi tipe data desimal dan disimpan ke dalam variabel `ipk_3003`.
#
# 2. **Baris 3** berfungsi untuk melakukan percabangan menggunakan `if` dengan kondisi `ipk_3003 > 2.75`, yaitu memeriksa apakah nilai IPK lebih besar dari 2,75.
#
# 3. **Baris 4** berfungsi untuk menampilkan pesan bahwa pengguna lulus sangat memuaskan beserta nilai IPK apabila kondisi pada `if` terpenuhi. Fungsi `str()` digunakan untuk mengubah nilai IPK menjadi teks agar dapat digabungkan dengan teks menggunakan operator `+`.
#
# 4. **Baris 5** merupakan bagian `else` yang berfungsi untuk menjalankan perintah ketika kondisi `if` tidak terpenuhi.
#
# 5. **Baris 6** berfungsi untuk menampilkan pesan **"Anda Tidak Lulus"** apabila nilai IPK tidak lebih dari 2,75.
#
# 6. **Baris 7** berfungsi untuk menampilkan pesan **"Program selesai"** setelah seluruh proses percabangan selesai dijalankan.

# %% [markdown]
# ### 2.2.3 Program "multi_if1_2611533003"

# %%
# Program ini menggunakan fungsi input()

umur_3003 = int(input("Masukkan umur Anda: "))
sim_3003 = input("Apakah Anda memiliki SIM c (y/t): ")[0]

if umur_3003 >= 17 and sim_3003 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")

if umur_3003 >= 17 and sim_3003 != 'y':
    print("Anda sudah dewasa tapi tidak boleh bawa motor")

if umur_3003 < 17 and sim_3003 != 'y':
    print("Anda belum cukup umur bawa motor")

if umur_3003 < 17 and sim_3003 == 'y':
    print("Anda belum cukup umur punya SIM")
# Out:
# Anda sudah dewasa dan boleh bawa motor

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan umur. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan menyimpannya ke dalam variabel `umur_3003`.
#
# 3. Baris 4 berfungsi untuk meminta informasi apakah pengguna memiliki SIM C. `[0]` digunakan untuk mengambil karakter pertama dari input, kemudian hasilnya disimpan dalam variabel `sim_3003`.
#
# 4. Baris 6 berfungsi untuk memeriksa apakah pengguna sudah berusia minimal 17 tahun dan memiliki SIM C. Operator `and` digunakan agar kedua kondisi harus terpenuhi. Jika benar, program menampilkan bahwa pengguna boleh membawa motor.
#
# 5. Baris 9 berfungsi untuk memeriksa apakah pengguna sudah berusia minimal 17 tahun tetapi tidak memiliki SIM C. Operator `!=` digunakan untuk menyatakan bahwa SIM bukan `y`. Jika kondisi terpenuhi, program menampilkan bahwa pengguna tidak boleh membawa motor.
#
# 6. Baris 12 berfungsi untuk memeriksa apakah pengguna belum berusia 17 tahun dan tidak memiliki SIM C. Jika kedua kondisi terpenuhi, program menampilkan bahwa pengguna belum cukup umur untuk membawa motor.
#
# 7. Baris 15 berfungsi untuk memeriksa apakah pengguna belum berusia 17 tahun tetapi memiliki SIM C. Jika kondisi terpenuhi, program menampilkan bahwa pengguna belum cukup umur untuk memiliki SIM.

# %% [markdown]
# ### 2.2.4 Program "multi_if2_2611533003"

# %%
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dari user
total_belanja_3003 = float(input("Masukkan total belanja (Rp): "))

# Input status member (mengecek apakah user mengetik 'y' atau 'ya')
input_member_3003 = input("Apakah Anda member? (y/t): ").strip().lower()
is_member = input_member_3003 in ["y", "ya"]

# Input status kode promo (mengecek apakah user mengetik 'y' atau 'ya')
input_promo_3003 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_3003 = input_promo_3003 in ["y", "ya"]

total_diskon_persen_3003 = 0

# Multi-IF terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_3003 > 1000000:
    total_diskon_persen_3003 += 10  # Diskon belanja besar

if is_member:
    total_diskon_persen_3003 += 5  # Diskon member

if kode_promo_valid_3003:
    total_diskon_persen_3003 += 15  # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_3003 = total_belanja_3003 * (total_diskon_persen_3003 / 100)
total_bayar_3003 = total_belanja_3003 - nominal_diskon_3003

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon  : {total_diskon_persen_3003}% (Rp {nominal_diskon_3003:,.0f})")
print(f"Total Bayar   : Rp {total_bayar_3003:,.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_3003}%")
# Output: Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promo valid
# Out:
# --- Rincian Pembayaran ---
# Total Diskon  : 20% (Rp 40,000)
# Total Bayar   : Rp 160,000
# Total diskon yang Anda dapatkan: 20%

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
#
# 2. Baris 2 merupakan komentar yang menjelaskan bahwa program digunakan untuk menghitung diskon belanja.
#
# 3. Baris 5 berfungsi untuk meminta pengguna memasukkan total belanja. Fungsi `float()` digunakan agar nilai yang dimasukkan dapat berupa bilangan desimal dan disimpan dalam variabel `total_belanja_3003`.
#
# 4. Baris 8 berfungsi untuk meminta status keanggotaan pengguna. Fungsi `.strip()` digunakan untuk menghapus spasi yang tidak diperlukan, sedangkan `.lower()` digunakan untuk mengubah input menjadi huruf kecil.
#
# 5. Baris 9 berfungsi untuk menentukan apakah pengguna merupakan member. Kondisi `in ["y", "ya"]` akan menghasilkan nilai `True` jika pengguna memasukkan `y` atau `ya`, kemudian hasilnya disimpan dalam variabel `is_member`.
#
# 6. Baris 12 berfungsi untuk meminta pengguna memasukkan status kode promo. Input dibersihkan menggunakan `.strip()` dan diubah menjadi huruf kecil menggunakan `.lower()`.
#
# 7. Baris 13 berfungsi untuk menentukan apakah kode promo yang dimasukkan valid. Jika pengguna memasukkan `y` atau `ya`, variabel `kode_promo_valid_3003` akan bernilai `True`.
#
# 8. Baris 15 berfungsi untuk menginisialisasi nilai total diskon sebesar `0%`. Nilai ini nantinya akan bertambah sesuai dengan kondisi yang terpenuhi.
#
# 9. Baris 20 berfungsi untuk memeriksa apakah total belanja lebih dari Rp1.000.000. Jika kondisi terpenuhi, program menambahkan diskon sebesar `10%` menggunakan operator `+=`.
#
# 10. Baris 23 berfungsi untuk memeriksa apakah pengguna merupakan member. Jika bernilai `True`, program menambahkan diskon member sebesar `5%`.
#
# 11. Baris 26 berfungsi untuk memeriksa apakah kode promo valid. Jika bernilai `True`, program menambahkan diskon voucher sebesar `15%`.
#
# 12. Baris 29 berfungsi untuk menghitung nominal diskon. Nilai total belanja dikalikan dengan persentase diskon yang telah dibagi `100` agar menjadi nilai desimal.
#
# 13. Baris 30 berfungsi untuk menghitung total pembayaran setelah dikurangi nominal diskon dari total belanja.
#
# 14. Baris 33 berfungsi untuk menampilkan judul bagian rincian pembayaran.
#
# 15. Baris 34 berfungsi untuk menampilkan total persentase diskon dan nominal diskon yang diperoleh. Format `:,.0f` digunakan agar nominal ditampilkan dengan pemisah ribuan tanpa angka desimal.
#
# 16. Baris 35 berfungsi untuk menampilkan total pembayaran setelah mendapatkan diskon.
#
# 17. Baris 37 berfungsi untuk menampilkan kembali jumlah total diskon yang diperoleh oleh pengguna.
#
# 18. Baris 38 merupakan komentar yang memberikan contoh hasil. Jika pengguna berbelanja lebih dari Rp1.000.000, merupakan member, dan memiliki kode promo yang valid, maka seluruh diskon akan terakumulasi menjadi 30%.

# %% [markdown]
# ### 2.2.5 Program "if_elif_else1_2611533003"

# %%
# Program ini menggunakan fungsi input()

umur_3003 = int(input("Input umur anda: "))
sim_3003 = input("Apakah Anda Sudah Punya Sim C: ")[0]

if umur_3003 >= 17 and sim_3003 == 'y':
    print("Anda Sudah dewasa dan boleh bawa motor")
elif umur_3003 >= 17 and sim_3003 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")
elif umur_3003 < 17 and sim_3003 == 'y':
    print("Anda Belum Cukup Umur punya SIM")
else:
    print("Anda Belum Cukup Umur dan tidak boleh bawa motor")

print("Program Selesai")
# Out:
# Anda Sudah dewasa dan boleh bawa motor
# Program Selesai

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan umur. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan disimpan dalam variabel `umur_3003`.
#
# 3. Baris 4 berfungsi untuk meminta pengguna memasukkan informasi apakah sudah memiliki SIM C. `[0]` digunakan untuk mengambil karakter pertama dari input dan disimpan dalam variabel `sim_3003`.
#
# 4. Baris 6 berfungsi untuk memeriksa apakah umur pengguna minimal 17 tahun dan memiliki SIM C. Operator `and` digunakan agar kedua kondisi harus terpenuhi.
#
# 5. Baris 7 berfungsi untuk menampilkan pesan bahwa pengguna sudah dewasa dan boleh membawa motor jika kondisi pada baris sebelumnya terpenuhi.
#
# 6. Baris 8 berfungsi untuk memeriksa apakah pengguna sudah berusia minimal 17 tahun tetapi tidak memiliki SIM C. Operator `!=` digunakan untuk menunjukkan bahwa input SIM bukan `y`.
#
# 7. Baris 9 berfungsi untuk menampilkan pesan bahwa pengguna sudah dewasa tetapi tidak boleh membawa motor jika kondisi kedua terpenuhi.
#
# 8. Baris 10 berfungsi untuk memeriksa apakah pengguna berusia kurang dari 17 tahun tetapi memiliki SIM C.
#
# 9. Baris 11 berfungsi untuk menampilkan pesan bahwa pengguna belum cukup umur untuk memiliki SIM jika kondisi ketiga terpenuhi.
#
# 10. Baris 12 merupakan bagian `else` yang berfungsi untuk menangani kondisi ketika semua kondisi sebelumnya tidak terpenuhi.
#
# 11. Baris 13 berfungsi untuk menampilkan pesan bahwa pengguna belum cukup umur dan tidak boleh membawa motor.
#
# 12. Baris 15 berfungsi untuk menampilkan pesan "Program Selesai" setelah seluruh proses percabangan selesai dijalankan.

# %% [markdown]
# ### 2.2.6 Program "nilai_2611533003"

# %%
# Program konversi nilai angka menjadi huruf

nilai_3003 = int(input("Inputkan nilai angka= "))

if nilai_3003 >= 81:
    print("A")
elif nilai_3003 >= 70:
    print("B")
elif nilai_3003 >= 60:
    print("C")
elif nilai_3003 >= 50:
    print("D")
else:
    print("E")
# Out:
# A

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program digunakan untuk mengubah nilai angka menjadi nilai huruf.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan nilai angka. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan menyimpannya dalam variabel `nilai_3003`.
#
# 3. Baris 5 berfungsi untuk memeriksa apakah nilai yang dimasukkan lebih besar atau sama dengan 81. Jika kondisi terpenuhi, program akan menjalankan perintah pada baris berikutnya.
#
# 4. Baris 6 berfungsi untuk menampilkan nilai huruf "A" jika nilai angka lebih besar atau sama dengan 81.
#
# 5. Baris 7 berfungsi untuk memeriksa kondisi berikutnya menggunakan `elif`, yaitu apakah nilai lebih besar atau sama dengan 70. Kondisi ini diperiksa jika kondisi sebelumnya tidak terpenuhi.
#
# 6. Baris 8 berfungsi untuk menampilkan nilai huruf "B" jika nilai angka berada pada rentang 70 sampai 80.
#
# 7. Baris 9 berfungsi untuk memeriksa apakah nilai lebih besar atau sama dengan 60 jika kondisi sebelumnya tidak terpenuhi.
#
# 8. Baris 10 berfungsi untuk menampilkan nilai huruf "C" jika nilai angka berada pada rentang 60 sampai 69.
#
# 9. Baris 11 berfungsi untuk memeriksa apakah nilai lebih besar atau sama dengan 50 jika seluruh kondisi sebelumnya tidak terpenuhi.
#
# 10. Baris 12 berfungsi untuk menampilkan nilai huruf "D" jika nilai angka berada pada rentang 50 sampai 59.
#
# 11. Baris 13 merupakan bagian `else` yang digunakan untuk menangani nilai yang tidak memenuhi seluruh kondisi sebelumnya.
#
# 12. Baris 14 berfungsi untuk menampilkan nilai huruf "E" jika nilai angka kurang dari 50.

# %% [markdown]
# ### 2.2.7 Program "match_case1_2611533003"

# %%
# Program konversi angka menjadi nama bulan

bulan_3003 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_3003:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# Maret

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 merupakan komentar yang menjelaskan bahwa program digunakan untuk mengubah angka menjadi nama bulan.
#
# 2. Baris 3 berfungsi untuk meminta pengguna memasukkan angka bulan dari 1 sampai 12. Fungsi `int()` digunakan untuk mengubah input menjadi bilangan bulat dan menyimpannya dalam variabel `bulan_3003`.
#
# 3. Baris 5 berfungsi untuk memulai struktur percabangan `match-case`. Nilai pada variabel `bulan_3003` akan dibandingkan dengan setiap `case` yang tersedia.
#
# 4. Baris 6–7 berfungsi untuk memeriksa apakah angka yang dimasukkan adalah 1. Jika sesuai, program menampilkan nama bulan "Januari".
#
# 5. Baris 8–9 berfungsi untuk memeriksa angka 2 dan menampilkan nama bulan "Februari" jika sesuai.
#
# 6. Baris 10–11 berfungsi untuk memeriksa angka 3 dan menampilkan nama bulan "Maret" jika sesuai.
#
# 7. Baris 12–13 berfungsi untuk memeriksa angka 4 dan menampilkan nama bulan "April" jika sesuai.
#
# 8. Baris 14–15 berfungsi untuk memeriksa angka 5 dan menampilkan nama bulan "Mei" jika sesuai.
#
# 9. Baris 16–17 berfungsi untuk memeriksa angka 6 dan menampilkan nama bulan "Juni" jika sesuai.
#
# 10. Baris 18–19 berfungsi untuk memeriksa angka 7 dan menampilkan nama bulan "Juli" jika sesuai.
#
# 11. Baris 20–21 berfungsi untuk memeriksa angka 8 dan menampilkan nama bulan "Agustus" jika sesuai.
#
# 12. Baris 22–23 berfungsi untuk memeriksa angka 9 dan menampilkan nama bulan "September" jika sesuai.
#
# 13. Baris 24–25 berfungsi untuk memeriksa angka 10 dan menampilkan nama bulan "Oktober" jika sesuai.
#
# 14. Baris 26–27 berfungsi untuk memeriksa angka 11 dan menampilkan nama bulan "November" jika sesuai.
#
# 15. Baris 28–29 berfungsi untuk memeriksa angka 12 dan menampilkan nama bulan "Desember" jika sesuai.
#
# 16. Baris 30–31 merupakan `case _` yang berfungsi sebagai kondisi default. Jika angka yang dimasukkan tidak sesuai dengan angka 1 sampai 12, program akan menampilkan pesan "Angka tidak valid".

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# Sebuah wahana rekreasi petualangan membutuhkan sistem loket berbasis konsol untuk menentukan jenis wahana, memverifikasi kelaikan pengunjung dengan kondisi majemuk (logical operators), menghitung diskon akumulatif menggunakan multi-if terpisah, serta mencetak audit status operasional.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas4__2611533003"

# %%
print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")

# 1. INPUT DATA PENGUNJUNG

nama_pengunjung_3003 = input("Masukkan Nama Pengunjung        : ")
umur_3003 = int(input("Input umur anda                 : "))
sim_3003 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()
jumlah_tiket_3003 = int(input("Masukkan jumlah tiket           : "))

# Validasi jumlah tiket menggunakan if tunggal
if jumlah_tiket_3003 <= 0:
    print("Peringatan: Kuota tiket tidak valid!")

# 2. PEMILIHAN PAKET WAHANA MENGGUNAKAN MATCH-CASE

print("\nPilihan Paket Wahana (1-5):")
print(" 1. Safari Rimba         (Rp 50,000)")
print(" 2. Arung Jeram          (Rp 75,000)")
print(" 3. Motor ATV Ekstrim    (Rp 120,000)")
print(" 4. Roller Coaster Kilat (Rp 100,000)")
print(" 5. All-Access VIP       (Rp 220,000)")

paket_3003 = int(input("Masukkan nomor paket (1-5) : "))

match paket_3003:
    case 1:
        nama_wahana_3003 = "Wahana Safari Rimba"
        harga_satuan_3003 = 50000

    case 2:
        nama_wahana_3003 = "Wahana Arung Jeram"
        harga_satuan_3003 = 75000

    case 3:
        nama_wahana_3003 = "Wahana Motor ATV Ekstrim"
        harga_satuan_3003 = 120000

    case 4:
        nama_wahana_3003 = "Wahana Roller Coaster Kilat"
        harga_satuan_3003 = 100000

    case 5:
        nama_wahana_3003 = "Wahana All-Access VIP"
        harga_satuan_3003 = 220000

    case _:
        print("Paket wahana tidak valid!")
        raise SystemExit


# 3. VALIDASI IZIN KENDALI WAHANA
#    Menggunakan if-elif-else dan operator logika

print("\n--- KELAYAKAN PENGENDARA WAHANA ---")

if paket_3003 == 3 and umur_3003 >= 17 and sim_3003 == 'y':
    status_akses_3003 = (
        "Anda sudah dewasa dan boleh mengendarai ATV sendiri."
    )

elif paket_3003 == 3 and umur_3003 >= 17 and sim_3003 != 'y':
    status_akses_3003 = (
        "Anda sudah dewasa tetapi tidak boleh bawa motor ATV "
        "(wajib didampingi instruktur)."
    )

elif paket_3003 == 3 and umur_3003 < 17 and sim_3003 == 'y':
    status_akses_3003 = (
        "Identitas tidak valid: Belum cukup umur memiliki SIM."
    )

elif paket_3003 == 3:
    status_akses_3003 = (
        "Anda belum cukup umur dan tidak boleh bawa motor ATV."
    )

elif umur_3003 >= 10:
    status_akses_3003 = (
        "Anda memenuhi syarat umur untuk wahana ini."
    )

else:
    status_akses_3003 = (
        "Anda belum cukup umur untuk wahana ini."
    )

print(f"Status Akses: {status_akses_3003}")


# 4. INPUT DATA DISKON

is_member_3003 = input("Apakah Anda member? (y/t)       : ").strip().lower()
kode_promo_valid_3003 = input(
    "Apakah kode promo valid? (y/t) : "
).strip().lower()


# 5. PERHITUNGAN SUBTOTAL

subtotal_3003 = harga_satuan_3003 * jumlah_tiket_3003


# 6. MULTI-IF UNTUK DISKON AKUMULATIF

total_diskon_persen_3003 = 0

# Diskon Belanja Besar
if subtotal_3003 >= 200000:
    total_diskon_persen_3003 += 10

# Diskon Member
if is_member_3003 in ['y', 'ya']:
    total_diskon_persen_3003 += 5

# Diskon Voucher Promo
if kode_promo_valid_3003 in ['y', 'ya']:
    total_diskon_persen_3003 += 15

# Diskon Tambahan Rombongan
if jumlah_tiket_3003 >= 5:
    total_diskon_persen_3003 += 5


# 7. PERHITUNGAN NOMINAL DISKON DAN TOTAL BAYAR

nominal_diskon_3003 = (
    subtotal_3003 * (total_diskon_persen_3003 / 100)
)

total_bayar_3003 = subtotal_3003 - nominal_diskon_3003


# 8. EVALUASI KELULUSAN AUDIT

if total_bayar_3003 > 300000:
    catatan_layanan_3003 = (
        "Selamat! Anda berhak mendapatkan Souvenir Gratis."
    )
else:
    catatan_layanan_3003 = (
        "Terima kasih telah berkunjung."
    )


# 9. RINCIAN PEMBAYARAN

print("\n--- Rincian Pembayaran ---")
print(f"Nama Pengunjung  : {nama_pengunjung_3003}")
print(f"Wahana           : {nama_wahana_3003}")
print(f"Harga Satuan     : Rp {harga_satuan_3003:,.0f}")
print(f"Jumlah Tiket     : {jumlah_tiket_3003}")
print(f"Subtotal Belanja : Rp {subtotal_3003:,.0f}")
print(
    f"Total Diskon     : {total_diskon_persen_3003}% "
    f"(Rp {nominal_diskon_3003:,.0f})"
)
print(f"Total Bayar      : Rp {total_bayar_3003:,.0f}")
print(f"Catatan Layanan  : {catatan_layanan_3003}")

print("\nProgram Selesai")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
#
# Pilihan Paket Wahana (1-5):
#  1. Safari Rimba         (Rp 50,000)
#  2. Arung Jeram          (Rp 75,000)
#  3. Motor ATV Ekstrim    (Rp 120,000)
#  4. Roller Coaster Kilat (Rp 100,000)
#  5. All-Access VIP       (Rp 220,000)
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.
#
# --- Rincian Pembayaran ---
# Nama Pengunjung  : Yuan
# Wahana           : Wahana Motor ATV Ekstrim
# Harga Satuan     : Rp 120,000
# Jumlah Tiket     : 2
# Subtotal Belanja : Rp 240,000
# Total Diskon     : 30% (Rp 72,000)
# Total Bayar      : Rp 168,000
# Catatan Layanan  : Terima kasih telah berkunjung.
#
# Program Selesai

# %% [markdown]
# **Penjelasan :** ### 2.2.8 Tugas 4 — Sistem Loket Alpro Adventure Park
#
# **Baris 1–5** berfungsi untuk menampilkan judul program serta meminta input data pengunjung berupa nama, umur, kepemilikan SIM C, dan jumlah tiket.
#
# **Baris 8–9** berfungsi untuk melakukan validasi jumlah tiket menggunakan `if` tunggal. Jika jumlah tiket kurang dari atau sama dengan 0, program akan menampilkan peringatan bahwa kuota tiket tidak valid.
#
# **Baris 13–18** berfungsi untuk menampilkan daftar pilihan paket wahana beserta harga masing-masing paket.
#
# **Baris 20** berfungsi untuk menerima input nomor paket wahana yang dipilih oleh pengguna dan mengubah input tersebut menjadi tipe data integer.
#
# **Baris 22–45** berfungsi untuk menentukan nama wahana dan harga satuan berdasarkan nomor paket yang dipilih menggunakan struktur `match-case`. `case 1` sampai `case 5` digunakan untuk menentukan lima pilihan wahana yang tersedia, sedangkan `case _` digunakan untuk menangani input paket yang tidak valid.
#
# **Baris 47–48** berfungsi untuk menghentikan program apabila pengguna memasukkan nomor paket yang tidak tersedia.
#
# **Baris 53–82** berfungsi untuk melakukan pemeriksaan kelayakan pengunjung dalam menggunakan wahana. Pada paket Motor ATV Ekstrim, kondisi diperiksa berdasarkan umur dan kepemilikan SIM C menggunakan operator logika `and` dan `!=`. Untuk paket selain ATV, kelayakan diperiksa berdasarkan umur minimal 10 tahun.
#
# **Baris 84** berfungsi untuk menampilkan hasil pemeriksaan kelayakan pengunjung berdasarkan kondisi yang telah dievaluasi sebelumnya.
#
# **Baris 88–92** berfungsi untuk meminta input status keanggotaan pengguna dan validitas kode promo. Input kemudian diubah menjadi huruf kecil menggunakan `.lower()` agar dapat dibandingkan dengan kondisi yang telah ditentukan.
#
# **Baris 97** berfungsi untuk menghitung subtotal belanja dengan mengalikan harga satuan wahana dengan jumlah tiket yang dibeli.
#
# **Baris 102–117** berfungsi untuk menghitung total diskon menggunakan beberapa `if` yang berdiri secara terpisah. Diskon diberikan berdasarkan subtotal belanja, status member, kode promo, dan jumlah tiket. Karena menggunakan multi-if, beberapa diskon dapat diperoleh dan dijumlahkan secara bersamaan.
#
# **Baris 122–127** berfungsi untuk menghitung nominal diskon dan total pembayaran. Nominal diskon diperoleh dari subtotal dikalikan persentase diskon, kemudian total pembayaran diperoleh dengan mengurangi subtotal dengan nominal diskon.
#
# **Baris 132–139** berfungsi untuk melakukan evaluasi akhir menggunakan `if-else`. Jika total pembayaran lebih dari Rp300.000, pengguna mendapatkan informasi bahwa dirinya berhak memperoleh souvenir gratis. Jika tidak, program menampilkan ucapan terima kasih.
#
# **Baris 144–159** berfungsi untuk menampilkan seluruh rincian transaksi, yaitu nama pengunjung, nama wahana, harga satuan, jumlah tiket, subtotal, total diskon, total pembayaran, dan catatan layanan. Format `:,.0f` digunakan untuk menampilkan nominal angka dengan pemisah ribuan tanpa angka desimal.
#
# **Baris 161** berfungsi untuk menampilkan pesan bahwa program telah selesai dijalankan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa struktur percabangan merupakan bagian penting dalam pemrograman Python karena digunakan untuk mengatur alur program berdasarkan kondisi tertentu. Dengan struktur percabangan, program dapat menentukan tindakan yang berbeda sesuai dengan data atau kondisi yang diberikan oleh pengguna.
#
# Dalam praktikum ini dipelajari beberapa bentuk struktur percabangan, yaitu if, if-else, if-elif-else, multi-if, dan match-case. Masing-masing memiliki cara penggunaan yang berbeda sesuai dengan kebutuhan program. if digunakan untuk satu kondisi, if-else digunakan untuk dua kemungkinan, sedangkan if-elif-else digunakan untuk menangani beberapa kondisi secara berurutan. Multi-if digunakan untuk memeriksa beberapa kondisi secara independen sehingga lebih dari satu kondisi dapat dijalankan. Sementara itu, match-case digunakan untuk memilih tindakan berdasarkan nilai yang sesuai dengan beberapa pilihan yang tersedia.
#
# Penggunaan operator logika seperti and, or, dan != juga dapat membantu membentuk kondisi yang lebih kompleks. Selain itu, penerapan struktur percabangan pada studi kasus Sistem Loket Alpro Adventure Park menunjukkan bahwa konsep percabangan dapat digunakan untuk menyelesaikan permasalahan yang lebih nyata, seperti pemilihan wahana, validasi kelayakan pengunjung, pemberian diskon, dan evaluasi hasil transaksi.
#
# Dengan melakukan praktikum ini, pemahaman mengenai struktur percabangan pada Python dapat menjadi dasar untuk mempelajari struktur kontrol dan konsep pemrograman yang lebih kompleks.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “The Python Tutorial: More Control Flow Tools,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/tutorial/controlflow.html [Diakses 23 September 2026].
#
# [2] Python Software Foundation, “Built-in Functions,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/library/functions.html [Diakses 23 September 2026].
#
# [3] Python Software Foundation, “Lexical Analysis: Formatted String Literals,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/reference/lexical_analysis.html [Diakses 23 September 2026].
#
# [4] Python Software Foundation, “The Python Language Reference,” Python Documentation. [Online]. Tersedia: https://docs.python.org/3/reference/ [Diakses 23 September 2026].
