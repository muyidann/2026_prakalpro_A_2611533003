# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Operator”**
#
# **Disusun Oleh :**
#
# **M. Yiwanu Marhudan**
#
# **2611533003**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji beserta syukur saya panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga saya dapat menyelesaikan laporan praktikum mengenai operator pada Python yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan mengenai jenis-jenis operator yang terdapat pada bahasa pemrograman Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah saya dapat memahami secara langsung konsep dan penggunaan berbagai jenis operator pada Python, seperti operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise. Selain itu, praktikum ini juga diharapkan dapat membantu saya memahami penggunaan operator dalam mengolah data dan menyelesaikan suatu permasalahan melalui program Python.
#
# Saya menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
# M. Yiwanu Marhudan

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Bahasa pemrograman merupakan salah satu bagian penting dalam pengembangan teknologi karena memungkinkan manusia memberikan instruksi kepada komputer untuk menyelesaikan suatu permasalahan. Dalam proses pemrograman, operator menjadi salah satu komponen dasar yang digunakan untuk melakukan perhitungan, perbandingan, pengambilan keputusan, serta pengolahan data.
#
# Python merupakan salah satu bahasa pemrograman yang menyediakan berbagai jenis operator dengan fungsi yang berbeda. Operator aritmatika dapat digunakan untuk melakukan perhitungan matematis, operator perbandingan digunakan untuk membandingkan nilai, sedangkan operator logika digunakan untuk menggabungkan beberapa kondisi. Selain itu, Python juga memiliki operator assignment, membership, identity, dan bitwise yang dapat digunakan sesuai dengan kebutuhan program.
#
# Pemahaman terhadap operator sangat diperlukan karena operator sering digunakan dalam pembuatan algoritma dan pengambilan keputusan di dalam program. Penggunaan beberapa jenis operator juga dapat digabungkan untuk menyelesaikan permasalahan yang lebih kompleks.
#
# Pada praktikum Pekan 3 ini, berbagai jenis operator Python dipelajari dan diterapkan dalam program. Salah satu penerapannya adalah melalui studi kasus sistem simulasi transaksi dan validasi akses toko. Program tersebut digunakan untuk menghitung transaksi pelanggan sekaligus menentukan status diskon, kelayakan promo, dan hak akses pelanggan berdasarkan kondisi tertentu.
#
# Dengan adanya praktikum ini, mahasiswa diharapkan tidak hanya memahami bentuk dan fungsi masing-masing operator, tetapi juga mampu menerapkannya secara terintegrasi dalam sebuah program Python.
#
# ## 1.2 Tujuan
# 1. Memahami konsep dan fungsi berbagai jenis operator pada bahasa pemrograman Python.
# 2. Mampu menggunakan operator aritmatika untuk melakukan perhitungan dalam program.
# 3. Mampu menggunakan operator assignment untuk memberikan dan memperbarui nilai variabel.
# 4. Mampu menggunakan operator perbandingan untuk menghasilkan nilai Boolean.
# 5. Mampu menggunakan operator logika untuk menggabungkan beberapa kondisi.
# 6. Mampu menggunakan operator membership untuk memeriksa keberadaan suatu nilai dalam sebuah data.
# 7. Mampu memahami perbedaan operator identity dengan operator perbandingan.
# 8. Mampu menggunakan operator bitwise untuk mengolah nilai dalam bentuk biner.
# 9. Mampu mengintegrasikan berbagai jenis operator ke dalam sebuah program untuk menyelesaikan studi kasus transaksi.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai berbagai jenis operator dalam Python.
# 2. Meningkatkan kemampuan dalam melakukan operasi dan pengolahan data menggunakan Python.
# 3. Melatih kemampuan dalam menggunakan kondisi dan logika pada sebuah program.
# 4. Memahami penerapan operator bitwise dalam pengolahan status berbasis biner.
# 5. Meningkatkan kemampuan dalam menggabungkan beberapa operator untuk menyelesaikan suatu permasalahan.
# 6. Melatih kemampuan dalam membuat dan menjelaskan program Python secara terstruktur.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# ### 2.1.1 Pengertian Operator
#
# Operator adalah simbol atau kata khusus yang digunakan untuk melakukan operasi terhadap satu atau lebih operand. Operand dapat berupa nilai, variabel, maupun objek. Dalam Python, operator digunakan untuk melakukan berbagai proses seperti perhitungan, perbandingan, penggabungan kondisi, hingga manipulasi nilai biner.
#
# Beberapa jenis operator yang digunakan dalam praktikum ini antara lain operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise.
#
# ### 2.1.2 Operator Aritmatika
#
# Operator aritmatika digunakan untuk melakukan operasi matematika. Beberapa operator aritmatika yang terdapat pada Python yaitu:
#
# Operator	Fungsi
# +	Penjumlahan
# -	Pengurangan
# *	Perkalian
# /	Pembagian
# //	Pembagian bulat
# %	Sisa pembagian atau modulus
# **	Perpangkatan
#
# Dalam program transaksi, operator aritmatika dapat digunakan untuk menghitung besar diskon, total pembayaran, rata-rata harga barang, dan sisa pembagian.
#
# ### 2.1.3 Operator Assignment
#
# Operator assignment digunakan untuk memberikan atau memperbarui nilai pada sebuah variabel. Operator dasar assignment adalah =.
# Python juga menyediakan augmented assignment, yaitu operator yang menggabungkan operasi aritmatika dengan assignment.
#
# Contohnya:
#
# nilai_3003 = 10
# nilai_3003 += 5
#
# Setelah operasi tersebut, nilai nilai_3003 menjadi 15.
#
# Beberapa augmented assignment yang umum digunakan yaitu +=, -=, *=, /=, dan lainnya.
#
# ### 2.1.4 Operator Perbandingan
#
# Operator perbandingan digunakan untuk membandingkan dua nilai. Hasil dari operator perbandingan berupa nilai Boolean, yaitu True atau False.
#
# Beberapa operator perbandingan antara lain:
#
# Operator	Fungsi
# ==	Sama dengan
# !=	Tidak sama dengan
# >	Lebih besar
# <	Lebih kecil
# >=	Lebih besar atau sama dengan
# <=	Lebih kecil atau sama dengan
#
# Dalam program transaksi, operator perbandingan digunakan untuk menentukan apakah total belanja telah mencapai batas minimum dan apakah jumlah barang telah memenuhi persyaratan.
#
# ### 2.1.5 Operator Logika
#
# Operator logika digunakan untuk menggabungkan atau membalik kondisi Boolean. Python memiliki tiga operator logika utama, yaitu and, or, dan not.
#
# and menghasilkan True jika seluruh kondisi bernilai True.
# or menghasilkan True jika setidaknya salah satu kondisi bernilai True.
# not membalik nilai Boolean.
#
# Contohnya:
#
# member_3003 = True
# belanja_3003 = True
#
# hasil_3003 = member_3003 and belanja_3003
#
# Hasil dari operasi tersebut adalah True.
#
# ### 2.1.6 Operator Membership
#
# Operator membership digunakan untuk memeriksa apakah suatu nilai terdapat di dalam suatu koleksi data seperti list, tuple, atau string.
#
# Operator membership yang digunakan dalam Python adalah:
#
# in
# not in
#
# Contohnya:
#
# kode_3003 = "HEMAT10"
# daftar_3003 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
#
# hasil_3003 = kode_3003 in daftar_3003
#
# Hasilnya adalah True karena kode HEMAT10 terdapat di dalam daftar.
#
# ### 2.1.7 Operator Identity
#
# Operator identity digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama.
#
# Operator identity terdiri dari:
#
# is
# is not
#
# Operator is membandingkan identitas objek, sedangkan == membandingkan nilai atau isi objek.
#
# Sebagai contoh, dua list dapat memiliki isi yang sama tetapi merupakan dua objek yang berbeda. Oleh karena itu, kedua list tersebut dapat menghasilkan True ketika dibandingkan dengan ==, tetapi False ketika dibandingkan menggunakan is.
#
# ### 2.1.8 Operator Bitwise
#
# Operator bitwise digunakan untuk melakukan operasi terhadap bilangan dalam representasi biner. Operator ini dapat digunakan untuk menggabungkan maupun memeriksa status tertentu yang direpresentasikan menggunakan bit.
#
# Beberapa operator bitwise yang digunakan dalam praktikum adalah:
#
# Operator	Fungsi
# &	AND bitwise
# |	OR bitwise
# ^	XOR bitwise
# <<	Left shift
# >>	Right shift
#
# Pada studi kasus transaksi, setiap kondisi pelanggan direpresentasikan menggunakan nilai bit:
#
# Nilai Bit	Kondisi
# 0001	Pelanggan merupakan member
# 0010	Total belanja ≥ Rp200.000
# 0100	Jumlah barang ≥ 3
# 1000	Kode promo tersedia
#
# Operator OR digunakan untuk menggabungkan beberapa kondisi menjadi satu kode status. Operator AND digunakan untuk memeriksa kondisi tertentu dari kode status. Sementara itu, XOR dapat digunakan untuk membandingkan perbedaan antara kode transaksi dan kode referensi.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "aritmatika_2611533003"

# %%
angka1_3003 = int(input("angka-1: "))
angka2_3003 = int(input("angka-2: "))

#Penjumlahan
hasil_3003 = angka1_3003 + angka2_3003
print("\nOperator penjumlahan")
print("hasil =", hasil_3003)

#Pengurangan
hasil_3003 = angka1_3003 - angka2_3003
print("\nOperator pengurangan")
print("hasil =", hasil_3003)

#Perkalian
hasil_3003 = angka1_3003 * angka2_3003
print("\nOperator perkalian")
print("hasil =", hasil_3003)

#Pembagian, pembagian bulat, dan sisa bagi
if angka2_3003 != 0:
    hasil_3003 = angka1_3003 / angka2_3003
    print("\nOperator pembagian")
    print("hasil =", hasil_3003)

    hasil_3003 = angka1_3003 // angka2_3003
    print("\nOperator pembagian bulat")
    print("hasil =", hasil_3003)

    hasil_3003 = angka1_3003 % angka2_3003
    print("\nOperator sisa bagi")
    print("hasil =", hasil_3003)
else:
    print("Angka kedua tidak boleh bernilai 0.")

#Pangkat
hasil_3003 = angka1_3003 ** angka2_3003
print("\nOperator pangkat")
print("hasil =", hasil_3003)
# Out:
# Operator penjumlahan
# hasil = 15
#
# Operator pengurangan
# hasil = 5
#
# Operator perkalian
# hasil = 50
#
# Operator pembagian
# hasil = 2.0
#
# Operator pembagian bulat
# hasil = 2
#
# Operator sisa bagi
# hasil = 0
#
# Operator pangkat
# hasil = 100000

# %% [markdown]
# **Penjelasan :**
#
# 1. Bagian 1 sampai 2 berfungsi untuk membuat variabel `angka1_3003` dan `angka2_3003` yang digunakan untuk menyimpan dua bilangan yang dimasukkan oleh pengguna. Fungsi `int(input())` digunakan untuk menerima input dalam bentuk bilangan bulat.
#
# 2. Bagian 4 sampai 6 berfungsi untuk melakukan operasi penjumlahan menggunakan operator `+`. Hasil penjumlahan dari `angka1_3003` dan `angka2_3003` disimpan ke dalam variabel `hasil_3003`, kemudian ditampilkan menggunakan fungsi `print()`.
#
# 3. Bagian 8 sampai 10 berfungsi untuk melakukan operasi pengurangan menggunakan operator `-`. Nilai `angka2_3003` dikurangi dari `angka1_3003`, kemudian hasilnya disimpan ke dalam variabel `hasil_3003` dan ditampilkan ke layar.
#
# 4. Bagian 12 sampai 14 berfungsi untuk melakukan operasi perkalian menggunakan operator `*`. Nilai `angka1_3003` dikalikan dengan `angka2_3003`, kemudian hasilnya disimpan ke dalam variabel `hasil_3003` dan ditampilkan.
#
# 5. Bagian 16 sampai 17 berfungsi untuk melakukan pengecekan menggunakan operator perbandingan `!=`. Kondisi tersebut digunakan untuk memastikan bahwa `angka2_3003` tidak bernilai 0 sebelum dilakukan operasi pembagian.
#
# 6. Bagian 18 sampai 20 berfungsi untuk melakukan operasi pembagian menggunakan operator `/`. Nilai `angka1_3003` dibagi dengan `angka2_3003`, kemudian hasilnya disimpan ke dalam variabel `hasil_3003` dan ditampilkan.
#
# 7. Bagian 22 sampai 24 berfungsi untuk melakukan operasi pembagian bulat menggunakan operator `//`. Operator tersebut menghasilkan hasil pembagian tanpa menyertakan bagian desimal, kemudian hasilnya ditampilkan.
#
# 8. Bagian 26 sampai 28 berfungsi untuk melakukan operasi sisa bagi atau modulus menggunakan operator `%`. Operator tersebut digunakan untuk mendapatkan sisa hasil pembagian antara `angka1_3003` dan `angka2_3003`.
#
# 9. Bagian 29 sampai 30 berfungsi untuk memberikan pesan kepada pengguna apabila `angka2_3003` bernilai 0. Hal ini dilakukan karena angka 0 tidak dapat digunakan sebagai pembagi.
#
# 10. Bagian 32 sampai 34 berfungsi untuk melakukan operasi perpangkatan menggunakan operator `**`. Nilai `angka1_3003` dipangkatkan dengan `angka2_3003`, kemudian hasilnya disimpan ke dalam variabel `hasil_3003` dan ditampilkan ke layar.

# %% [markdown]
# ### 2.2.2 Program "assignment_2611533003"

# %%
angka1_3003 = int(input("angka-1: "))
angka2_3003 = int(input("angka-2: "))

print("\nNilai awal angka1_3003 =", angka1_3003)
print("Nilai awal angka2_3003 =", angka2_3003)

# Assignment biasa
hasil_3003 = angka1_3003
print("\nAssignment biasa (=)")
print("hasil =", hasil_3003)

# Assignment penambahan
hasil_3003 = angka1_3003
hasil_3003 += angka2_3003
print("\nAssignment penambahan (+=)")
print("hasil =", hasil_3003)

# Assignment pengurangan
hasil_3003 = angka1_3003
hasil_3003 -= angka2_3003
print("\nAssignment pengurangan (-=)")
print("hasil =", hasil_3003)

# Assignment perkalian
hasil_3003 = angka1_3003
hasil_3003 *= angka2_3003
print("\nAssignment perkalian (*=)")
print("hasil =", hasil_3003)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3003 != 0:
    hasil_3003 = angka1_3003
    hasil_3003 /= angka2_3003
    print("\nAssignment pembagian (/=)")
    print("hasil =", hasil_3003)

    #Operator tambahan
    hasil_3003 = angka1_3003
    hasil_3003 //= angka2_3003
    print("\nAssignment pembagian bulat (//=)")
    print("hasil =", hasil_3003)
    hasil_3003 = angka1_3003
    hasil_3003 %= angka2_3003
    print("\nAssignment sisa bagi (%=)")
    print("hasil =", hasil_3003)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_3003 = angka1_3003
hasil_3003 **= angka2_3003
print("\nAssignment perpangkatan (**=)")
print("hasil =", hasil_3003)
# Out:
# Nilai awal angka1_3003 = 10
# Nilai awal angka2_3003 = 5
#
# Assignment biasa (=)
# hasil = 10
#
# Assignment penambahan (+=)
# hasil = 15
#
# Assignment pengurangan (-=)
# hasil = 5
#
# Assignment perkalian (*=)
# hasil = 50
#
# Assignment pembagian (/=)
# hasil = 2.0
#
# Assignment pembagian bulat (//=)
# hasil = 2
#
# Assignment sisa bagi (%=)
# hasil = 0
#
# Assignment perpangkatan (**=)
# hasil = 100000

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 5** berfungsi untuk menerima dua angka dari pengguna dan menampilkan nilai awal dari variabel `angka1_3003` dan `angka2_3003`.
#
# 2. **Bagian 7 sampai 10** berfungsi untuk melakukan assignment biasa menggunakan operator `=` dengan menyimpan nilai `angka1_3003` ke dalam variabel `hasil_3003`, kemudian menampilkan hasilnya.
#
# 3. **Bagian 12 sampai 16** berfungsi untuk melakukan assignment penambahan menggunakan operator `+=`, yaitu menambahkan nilai `angka2_3003` ke dalam nilai `hasil_3003`.
#
# 4. **Bagian 18 sampai 22** berfungsi untuk melakukan assignment pengurangan menggunakan operator `-=`, yaitu mengurangi nilai `hasil_3003` dengan nilai `angka2_3003`.
#
# 5. **Bagian 24 sampai 28** berfungsi untuk melakukan assignment perkalian menggunakan operator `*=`, yaitu mengalikan nilai `hasil_3003` dengan nilai `angka2_3003`.
#
# 6. **Bagian 30 sampai 31** berfungsi untuk menentukan kondisi pembagian dengan memeriksa apakah `angka2_3003` tidak sama dengan 0 menggunakan operator `!=`.
#
# 7. **Bagian 32 sampai 35** berfungsi untuk melakukan assignment pembagian menggunakan operator `/=`, yaitu membagi nilai `hasil_3003` dengan `angka2_3003` dan menampilkan hasilnya.
#
# 8. **Bagian 37 sampai 41** berfungsi untuk melakukan assignment pembagian bulat menggunakan operator `//=`, yaitu membagi nilai `hasil_3003` dengan `angka2_3003` dan menghasilkan nilai pembagian tanpa angka desimal.
#
# 9. **Bagian 42 sampai 45** berfungsi untuk melakukan assignment sisa bagi menggunakan operator `%=`, yaitu mencari sisa hasil pembagian `hasil_3003` dengan `angka2_3003`.
#
# 10. **Bagian 46 sampai 48** berfungsi untuk menangani kondisi ketika `angka2_3003` bernilai 0. Program akan menampilkan pesan bahwa pembagian tidak dapat dilakukan.
#
# 11. **Bagian 50 sampai 54** berfungsi untuk melakukan assignment perpangkatan menggunakan operator `**=`, yaitu memangkatkan nilai `hasil_3003` dengan `angka2_3003` dan menampilkan hasilnya.

# %% [markdown]
# ### 2.2.3 Program "perbandingan_2611533003"

# %%
angka1_3003 = int(input("Input angka-1: "))
angka2_3003 = int(input("Input angka-2: "))

#lebih besar
hasil_3003 = angka1_3003 > angka2_3003
print("\nOperator lebih besar")
print("angka1_3003 > angka2_3003 =", hasil_3003)

#lebih kecil
hasil_3003 = angka1_3003 < angka2_3003
print("\nOperator lebih kecil")
print("angka1_3003 < angka2_3003 =", hasil_3003)

#lebih besar dari atau sama dengan
hasil_3003 = angka1_3003 >= angka2_3003
print("\nOperator lebih besar dari atau sama dengan")
print("angka1_3003 >= angka2_3003 =", hasil_3003)

#lebih kecil dari atau sama dengan
hasil_3003 = angka1_3003 <= angka2_3003
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1_3003 <= angka2_3003 =", hasil_3003)

#sama dengan
hasil_3003 = angka1_3003 == angka2_3003
print("\nOperator sama dengan")
print("angka1_3003 == angka2_3003 =", hasil_3003)

#tidak sama dengan
hasil_3003 = angka1_3003 != angka2_3003
print("\nOperator tidak sama dengan")
print("angka1_3003 != angka2_3003 =", hasil_3003)

#Tambah: perbandingan berantai dalam python
hasil_3003 = 0 < angka1_3003 < 100
print("\nOperator perbandingan berantai")
print("0 < angka1_3003 < 100 =", hasil_3003)

hasil_3003 = 0 < angka2_3003 < 100
print("0 < angka2_3003 < 100 =", hasil_3003)
# Out:
# Operator lebih besar
# angka1_3003 > angka2_3003 = True
#
# Operator lebih kecil
# angka1_3003 < angka2_3003 = False
#
# Operator lebih besar dari atau sama dengan
# angka1_3003 >= angka2_3003 = True
#
# Operator lebih kecil dari atau sama dengan
# angka1_3003 <= angka2_3003 = False
#
# Operator sama dengan
# angka1_3003 == angka2_3003 = False
#
# Operator tidak sama dengan
# angka1_3003 != angka2_3003 = True
#
# Operator perbandingan berantai
# 0 < angka1_3003 < 100 = True
# 0 < angka2_3003 < 100 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 2** berfungsi untuk menerima dua angka dari pengguna dan menyimpannya ke dalam variabel `angka1_3003` dan `angka2_3003`.
#
# 2. **Bagian 4 sampai 7** berfungsi untuk membandingkan apakah `angka1_3003` lebih besar dari `angka2_3003` menggunakan operator `>` dan menampilkan hasil perbandingannya.
#
# 3. **Bagian 9 sampai 12** berfungsi untuk membandingkan apakah `angka1_3003` lebih kecil dari `angka2_3003` menggunakan operator `<` dan menampilkan hasilnya.
#
# 4. **Bagian 14 sampai 17** berfungsi untuk membandingkan apakah `angka1_3003` lebih besar dari atau sama dengan `angka2_3003` menggunakan operator `>=`.
#
# 5. **Bagian 19 sampai 22** berfungsi untuk membandingkan apakah `angka1_3003` lebih kecil dari atau sama dengan `angka2_3003` menggunakan operator `<=`.
#
# 6. **Bagian 24 sampai 27** berfungsi untuk membandingkan apakah `angka1_3003` sama dengan `angka2_3003` menggunakan operator `==`.
#
# 7. **Bagian 29 sampai 32** berfungsi untuk membandingkan apakah `angka1_3003` tidak sama dengan `angka2_3003` menggunakan operator `!=`.
#
# 8. **Bagian 34 sampai 37** berfungsi untuk melakukan perbandingan berantai dengan kondisi `0 < angka1_3003 < 100`, kemudian menyimpan dan menampilkan hasilnya.
#
# 9. **Bagian 38 sampai 40** berfungsi untuk melakukan perbandingan berantai dengan kondisi `0 < angka2_3003 < 100`, kemudian menyimpan dan menampilkan hasilnya.

# %% [markdown]
# ### 2.2.4 Program "logika_2611533003"

# %%
#memasukkan nilai boolean
a1_3003 = input("Input nilai boolean-1 (True/False): ").strip().lower() == "true"
a2_3003 = input("Input nilai boolean-2 (True/False): ").strip().lower() == "true"

print("\nA1 = ", a1_3003)
print("A2 = ", a2_3003)

# Konjungsi: bernilai True jika keduanya True
hasil_3003 = a1_3003 and a2_3003
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_3003)

# Disjungsi: bernilai True jika salah satunya True
hasil_3003 = a1_3003 or a2_3003
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_3003)

# Negasi A1: mambalikan nilai A1
hasil_3003 = not a1_3003
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_3003)

# Negasi A2: membalikan nilai A2
hasil_3003 = not a2_3003
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_3003)

# XOR: bernilai True jika Kedua nilai berbeda
hasil_3003 = a1_3003 != a2_3003
print("\nDisjungsi eksklusif (XOR)")
print("A1 XOR A2 =", hasil_3003)
# Out:
# A1 =  True
# A2 =  False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = True
#
# Disjungsi eksklusif (XOR)
# A1 XOR A2 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 5** berfungsi untuk menerima dua nilai boolean dari pengguna, mengubah input menjadi nilai `True` atau `False`, kemudian menampilkan nilai dari `a1_3003` dan `a2_3003`.
#
# 2. **Bagian 7 sampai 10** berfungsi untuk melakukan operasi konjungsi menggunakan operator `and`. Hasil akan bernilai `True` apabila kedua nilai `a1_3003` dan `a2_3003` bernilai `True`.
#
# 3. **Bagian 12 sampai 15** berfungsi untuk melakukan operasi disjungsi menggunakan operator `or`. Hasil akan bernilai `True` apabila salah satu atau kedua nilai bernilai `True`.
#
# 4. **Bagian 17 sampai 20** berfungsi untuk melakukan operasi negasi terhadap nilai `a1_3003` menggunakan operator `not`, sehingga nilai `True` akan menjadi `False` dan sebaliknya.
#
# 5. **Bagian 22 sampai 25** berfungsi untuk melakukan operasi negasi terhadap nilai `a2_3003` menggunakan operator `not`, sehingga nilai boolean yang dimasukkan akan dibalik.
#
# 6. **Bagian 27 sampai 30** berfungsi untuk melakukan operasi XOR atau disjungsi eksklusif dengan membandingkan `a1_3003` dan `a2_3003` menggunakan operator `!=`. Hasil akan bernilai `True` apabila kedua nilai boolean berbeda.

# %% [markdown]
# ### 2.2.5 Program "lainnya_2611533003"

# %%
print("==================================")
print("1. OPERATOR KEANGGOTAAN")
print("==================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_3003 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_3003 = [int(angka.strip()) for angka in input_data_3003.split(",")]

nilai_dicari_3003 = int(input("Masukkan angka yang ingin dicari: "))

# Operator In
hasil_3003 = nilai_dicari_3003 in data_3003
print("\nOperator keanggotaan IN")
print(nilai_dicari_3003, "in", data_3003, "=", hasil_3003)

# Operator Not In
hasil_3003 = nilai_dicari_3003 not in data_3003
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_3003, "not in", data_3003, "=", hasil_3003)

print("\n==================================")
print("2. OPERATOR IDENTITAS")
print("==================================")

# objek1 menggunakan list dari input pengguna
objek1_3003 = data_3003

# objek2 menggunakan list dari input pengguna
objek2_3003 = objek1_3003

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_3003 = data_3003.copy()

print("objek1_3003 =", objek1_3003)
print("objek2_3003 =", objek2_3003)
print("objek3_3003 =", objek3_3003)

# Operator Is
hasil_3003 = objek1_3003 is objek2_3003
print("\nOperator identitas IS")
print("objek1_3003 is objek2_3003 =", hasil_3003)

# Operator Is Not
hasil_3003 = objek1_3003 is not objek3_3003
print("\nOperator identitas IS NOT")
print("objek1_3003 is not objek3_3003 =", hasil_3003)

# Membandingkan identitas dan nilai
print("\nMembandingkan identitas dan nilai:")
print("objek1_3003 is objek3_3003 =", objek1_3003 is objek3_3003)
print("objek1_3003 == objek3_3003 =", objek1_3003 == objek3_3003)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 5 in [10] = False
#
# Operator keanggotaan NOT IN
# 5 not in [10] = True
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1_3003 = [10]
# objek2_3003 = [10]
# objek3_3003 = [10]
#
# Operator identitas IS
# objek1_3003 is objek2_3003 = True
#
# Operator identitas IS NOT
# objek1_3003 is not objek3_3003 = True
#
# Membandingkan identitas dan nilai:
# objek1_3003 is objek3_3003 = False
# objek1_3003 == objek3_3003 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 3** berfungsi untuk menampilkan judul program mengenai operator keanggotaan.
#
# 2. **Bagian 5 sampai 6** berfungsi untuk menerima beberapa angka dari pengguna yang dipisahkan dengan tanda koma dan menyimpannya ke dalam variabel `input_data_3003`.
#
# 3. **Bagian 8 sampai 8** berfungsi untuk mengubah data yang dimasukkan pengguna menjadi list berisi bilangan integer. Fungsi `split(",")` digunakan untuk memisahkan data berdasarkan koma, sedangkan `strip()` digunakan untuk menghilangkan spasi.
#
# 4. **Bagian 10 sampai 10** berfungsi untuk menerima angka yang ingin dicari oleh pengguna dan menyimpannya ke dalam variabel `nilai_dicari_3003`.
#
# 5. **Bagian 12 sampai 15** berfungsi untuk menggunakan operator keanggotaan `in` untuk memeriksa apakah `nilai_dicari_3003` terdapat di dalam `data_3003`, kemudian menampilkan hasil pemeriksaannya.
#
# 6. **Bagian 17 sampai 20** berfungsi untuk menggunakan operator keanggotaan `not in` untuk memeriksa apakah `nilai_dicari_3003` tidak terdapat di dalam `data_3003`, kemudian menampilkan hasilnya.
#
# 7. **Bagian 22 sampai 24** berfungsi untuk menampilkan judul bagian operator identitas.
#
# 8. **Bagian 26 sampai 27** berfungsi untuk membuat `objek1_3003` yang merujuk pada list `data_3003`.
#
# 9. **Bagian 29 sampai 30** berfungsi untuk membuat `objek2_3003` yang merujuk pada objek yang sama dengan `objek1_3003`.
#
# 10. **Bagian 32 sampai 33** berfungsi untuk membuat `objek3_3003` sebagai objek list baru dengan isi yang sama seperti `data_3003` menggunakan fungsi `copy()`.
#
# 11. **Bagian 35 sampai 37** berfungsi untuk menampilkan nilai dari `objek1_3003`, `objek2_3003`, dan `objek3_3003`.
#
# 12. **Bagian 39 sampai 42** berfungsi untuk menggunakan operator identitas `is` untuk memeriksa apakah `objek1_3003` dan `objek2_3003` merupakan objek yang sama, kemudian menampilkan hasilnya.
#
# 13. **Bagian 44 sampai 47** berfungsi untuk menggunakan operator identitas `is not` untuk memeriksa apakah `objek1_3003` dan `objek3_3003` merupakan objek yang berbeda, kemudian menampilkan hasilnya.
#
# 14. **Bagian 49 sampai 52** berfungsi untuk membandingkan identitas dan nilai dari `objek1_3003` dan `objek3_3003`. Operator `is` digunakan untuk membandingkan identitas objek, sedangkan operator `==` digunakan untuk membandingkan isi atau nilai kedua objek.

# %% [markdown]
# ### 2.2.6 Program "bitwise_2611533003"

# %%
print("\n==================================")
print("3. OPERATOR BITWISE")
print("==================================")

angka1_3003 = int(input("Masukkan angka bitwise-1: "))
angka2_3003 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner:")
print("Angka 1:", angka1_3003, "-| biner", bin(angka1_3003))
print("Angka 2:", angka2_3003, "-| biner", bin(angka2_3003))

# Bitwise AND
hasil_3003 = angka1_3003 & angka2_3003
print("\nBitwise AND (&)")
print(angka1_3003, "&", angka2_3003, "=", hasil_3003)
print("Biner hasil =", bin(hasil_3003))
print("Biner hasil (8 bit) =", format(hasil_3003, '08b'))

# Bitwise OR
hasil_3003 = angka1_3003 | angka2_3003
print("\nBitwise OR (|)")
print(angka1_3003, "|", angka2_3003, "=", hasil_3003)
print("Biner hasil =", bin(hasil_3003))
print("Biner hasil (8 bit) =", format(hasil_3003, '08b'))

# Bitwise XOR
hasil_3003 = angka1_3003 ^ angka2_3003
print("\nBitwise XOR (^)")
print(angka1_3003, "^", angka2_3003, "=", hasil_3003)
print("Biner hasil =", bin(hasil_3003))
print("Biner hasil (8 bit) =", format(hasil_3003, '08b'))

# Bitwise NOT
hasil_3003 = ~angka1_3003
print("\nBitwise NOT (~)")
print("~", angka1_3003, "=", hasil_3003)
print("Biner hasil =", bin(hasil_3003))
print("Biner hasil (8 bit) =", format(hasil_3003, '08b'))

# Bitwise geser kiri
jumlah_geser_3003 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_3003 = angka1_3003 << jumlah_geser_3003
print("\nBitwise Geser Kiri (<<)")
print(angka1_3003, "<<", jumlah_geser_3003, "=", hasil_3003)
print("Biner hasil =", bin(hasil_3003))
print("Biner hasil (8 bit) =", format(hasil_3003, '08b'))

# Bitwise geser kanan
hasil_3003 = angka1_3003 >> jumlah_geser_3003
print("\nBitwise Geser Kanan (>>)")
print(angka1_3003, ">>", jumlah_geser_3003, "=", hasil_3003)
print("Biner hasil =", bin(hasil_3003))
print("Biner hasil (8 bit) =", format(hasil_3003, '08b'))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner:
# Angka 1: 10 -| biner 0b1010
# Angka 2: 5 -| biner 0b101
#
# Bitwise AND (&)
# 10 & 5 = 0
# Biner hasil = 0b0
# Biner hasil (8 bit) = 00000000
#
# Bitwise OR (|)
# 10 | 5 = 15
# Biner hasil = 0b1111
# Biner hasil (8 bit) = 00001111
#
# Bitwise XOR (^)
# 10 ^ 5 = 15
# Biner hasil = 0b1111
# Biner hasil (8 bit) = 00001111
#
# Bitwise NOT (~)
# ~ 10 = -11
# Biner hasil = -0b1011
# Biner hasil (8 bit) = -0001011
#
# Bitwise Geser Kiri (<<)
# 10 << 2 = 40
# Biner hasil = 0b101000
# Biner hasil (8 bit) = 00101000
#
# Bitwise Geser Kanan (>>)
# 10 >> 2 = 2
# Biner hasil = 0b10
# Biner hasil (8 bit) = 00000010

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 3** berfungsi untuk menampilkan judul program yang menunjukkan bahwa kode membahas operator bitwise.
#
# 2. **Bagian 5 sampai 6** berfungsi untuk menerima dua angka dari pengguna yang akan digunakan dalam operasi bitwise.
#
# 3. **Bagian 8 sampai 10** berfungsi untuk menampilkan nilai kedua angka dalam bentuk desimal dan biner menggunakan fungsi `bin()`.
#
# 4. **Bagian 12 sampai 17** berfungsi untuk melakukan operasi Bitwise AND menggunakan operator `&`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 5. **Bagian 19 sampai 24** berfungsi untuk melakukan operasi Bitwise OR menggunakan operator `|`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 6. **Bagian 26 sampai 31** berfungsi untuk melakukan operasi Bitwise XOR menggunakan operator `^`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 7. **Bagian 33 sampai 38** berfungsi untuk melakukan operasi Bitwise NOT menggunakan operator `~` terhadap `angka1_3003`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 8. **Bagian 40 sampai 41** berfungsi untuk menentukan dan menerima jumlah pergeseran bit dari pengguna yang akan digunakan dalam operasi Bitwise geser kiri dan geser kanan.
#
# 9. **Bagian 43 sampai 47** berfungsi untuk melakukan operasi Bitwise geser kiri menggunakan operator `<<`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 10. **Bagian 49 sampai 54** berfungsi untuk melakukan operasi Bitwise geser kanan menggunakan operator `>>`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
#  Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas3_2611533003"

# %%
print("=== SISTEM TRANSAKSI TOKO ===")

nama_3003 = input("Masukkan Nama Pelanggan : ")
status_3003 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_3003 = float(input("Masukkan Total Belanja : Rp"))
jumlah_barang_3003 = int(input("Masukkan Jumlah Barang : "))
kode_promo_3003 = input("Masukkan Kode Promo : ").upper()

syarat_belanja_3003 = total_belanja_3003 >= 200000
syarat_barang_3003 = jumlah_barang_3003 >= 3
status_member_3003 = status_3003 == "member"

daftar_promo_3003 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

promo_tersedia_3003 = kode_promo_3003 in daftar_promo_3003
promo_tidak_tersedia_3003 = kode_promo_3003 not in daftar_promo_3003

diskon_member_3003 = status_member_3003 and syarat_belanja_3003

promo_didapatkan_3003 = promo_tersedia_3003 and (syarat_belanja_3003 or syarat_barang_3003)

bukan_member_3003 = not status_member_3003

if diskon_member_3003:
    persentase_diskon_3003 = 0.10
else:
    persentase_diskon_3003 = 0.05 if syarat_belanja_3003 else 0

besar_diskon_3003 = total_belanja_3003 * persentase_diskon_3003

total_pembayaran_3003 = total_belanja_3003 - besar_diskon_3003

if jumlah_barang_3003 > 0:
    rata_rata_barang_3003 = total_belanja_3003 / jumlah_barang_3003
else:
    rata_rata_barang_3003 = 0

sisa_pembagian_3003 = int(total_belanja_3003) % jumlah_barang_3003 if jumlah_barang_3003 > 0 else 0


poin_3003 = 0
if status_member_3003:
    poin_3003 += int(total_pembayaran_3003 // 10000)

jumlah_barang_tersisa_3003 = jumlah_barang_3003
if promo_didapatkan_3003:
    jumlah_barang_tersisa_3003 -= 1

kode_1_3003 = ["HEMAT10"]
kode_2_3003 = ["HEMAT10"]

nilai_sama_3003 = kode_1_3003 == kode_2_3003
objek_sama_3003 = kode_1_3003 is kode_2_3003
objek_berbeda_3003 = kode_1_3003 is not kode_2_3003


kode_member_3003 = 1 if status_member_3003 else 0
kode_belanja_3003 = 2 if syarat_belanja_3003 else 0
kode_barang_3003 = 4 if syarat_barang_3003 else 0
kode_promo_3003 = 8 if promo_tersedia_3003 else 0

# Operator OR (|)
kode_status_3003 = (
    kode_member_3003
    | kode_belanja_3003
    | kode_barang_3003
    | kode_promo_3003
)

cek_member_3003 = kode_status_3003 & 1
cek_belanja_3003 = kode_status_3003 & 2
cek_barang_3003 = kode_status_3003 & 4
cek_promo_3003 = kode_status_3003 & 8

kode_referensi_3003 = 11
perbandingan_status_3003 = kode_status_3003 ^ kode_referensi_3003

kode_shift_3003 = kode_status_3003 << 1


member_access_3003 = bool(cek_member_3003)
promo_access_3003 = bool(cek_promo_3003)
free_shipping_access_3003 = syarat_belanja_3003 and syarat_barang_3003


print("\n=== DATA PELANGGAN ===")
print("Nama Pelanggan       :", nama_3003)
print("Status Pelanggan     :", status_3003)
print("Total Belanja        : Rp", total_belanja_3003)
print("Jumlah Barang        :", jumlah_barang_3003)
print("Kode Promo           :", kode_promo_3003)


print("\n=== HASIL VALIDASI ===")
print("Belanja >= Rp200000  :", syarat_belanja_3003)
print("Jumlah Barang >= 3   :", syarat_barang_3003)
print("Status Member        :", status_member_3003)
print("Kode Promo Tersedia  :", promo_tersedia_3003)
print("Mendapatkan Diskon   :", diskon_member_3003)
print("Mendapatkan Promo    :", promo_didapatkan_3003)


print("\n=== HASIL PERHITUNGAN ===")
print("Besarnya Diskon      : Rp", besar_diskon_3003)
print("Total Pembayaran     : Rp", total_pembayaran_3003)
print("Rata-rata Harga      : Rp", rata_rata_barang_3003)
print("Sisa Pembagian       :", sisa_pembagian_3003)


print("\n=== HAK AKSES PELANGGAN ===")
print("Kode Hak Akses       :", format(kode_status_3003, "04b"))
print("Member Access        :", member_access_3003)
print("Promo Access         :", promo_access_3003)
print("Free Shipping Access :", free_shipping_access_3003)
print("Poin Pelanggan       :", poin_3003)


print("\n=== OPERATOR IDENTITAS ===")
print("kode_1 == kode_2     :", nilai_sama_3003)
print("kode_1 is kode_2     :", objek_sama_3003)
print("kode_1 is not kode_2 :", objek_berbeda_3003)


print("\n=== OPERASI BITWISE ===")
print("Kode Status Transaksi")
print("0001 | 0010 | 0100 | 1000")

print("Kode Biner           :", format(kode_status_3003, "04b"))
print("Kode Desimal         :", kode_status_3003)

print("\n=== PEMERIKSAAN STATUS ===")

print("\nCek Member")
print(format(kode_status_3003, "04b"), "& 0001")
print("Hasil Biner         :", format(cek_member_3003, "04b"))
print("Hasil Desimal       :", cek_member_3003)

print("\nCek Belanja")
print(format(kode_status_3003, "04b"), "& 0010")
print("Hasil Biner         :", format(cek_belanja_3003, "04b"))
print("Hasil Desimal       :", cek_belanja_3003)

print("\nCek Jumlah Barang")
print(format(kode_status_3003, "04b"), "& 0100")
print("Hasil Biner         :", format(cek_barang_3003, "04b"))
print("Hasil Desimal       :", cek_barang_3003)

print("\nCek Promo")
print(format(kode_status_3003, "04b"), "& 1000")
print("Hasil Biner         :", format(cek_promo_3003, "04b"))
print("Hasil Desimal       :", cek_promo_3003)

print("\n=== PERBANDINGAN STATUS (XOR) ===")
print("Kode Transaksi      :", format(kode_status_3003, "04b"))
print("Kode Referensi      :", format(kode_referensi_3003, "04b"))
print(format(kode_status_3003, "04b"), "^",
      format(kode_referensi_3003, "04b"))
print("Hasil Biner         :", format(perbandingan_status_3003, "04b"))
print("Hasil Desimal       :", perbandingan_status_3003)

print("\n=== SHIFT ===")
print(format(kode_status_3003, "04b"), "<< 1")
print("Hasil Biner         :", format(kode_shift_3003, "b"))
print("Hasil Desimal       :", kode_shift_3003)

print("\n=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
# === DATA PELANGGAN ===
# Nama Pelanggan       : Yuan
# Status Pelanggan     : member
# Total Belanja        : Rp 300000.0
# Jumlah Barang        : 5
# Kode Promo           : 8
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000  : True
# Jumlah Barang >= 3   : True
# Status Member        : True
# Kode Promo Tersedia  : True
# Mendapatkan Diskon   : True
# Mendapatkan Promo    : True
#
# === HASIL PERHITUNGAN ===
# Besarnya Diskon      : Rp 30000.0
# Total Pembayaran     : Rp 270000.0
# Rata-rata Harga      : Rp 60000.0
# Sisa Pembagian       : 0
#
# === HAK AKSES PELANGGAN ===
# Kode Hak Akses       : 1111
# Member Access        : True
# Promo Access         : True
# Free Shipping Access : True
# Poin Pelanggan       : 27
#
# === OPERATOR IDENTITAS ===
# kode_1 == kode_2     : True
# kode_1 is kode_2     : False
# kode_1 is not kode_2 : True
#
# === OPERASI BITWISE ===
# Kode Status Transaksi
# 0001 | 0010 | 0100 | 1000
# Kode Biner           : 1111
# ...

# %% [markdown]
# **Penjelasan :**
# 1. Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.
#
# Program menggunakan beberapa operator aritmatika, yaitu perkalian (*) untuk menghitung besar diskon, pengurangan (-) untuk menghitung total pembayaran setelah diskon, pembagian (/) untuk menghitung rata-rata harga barang, pembagian bulat (//) untuk menghitung poin pelanggan, dan modulus (%) untuk mendapatkan sisa pembagian total belanja dengan jumlah barang. Operator tersebut digunakan agar perhitungan transaksi dapat dilakukan secara otomatis berdasarkan input pengguna.
#
# 2. Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.
#
# Operator and menghasilkan True apabila semua kondisi yang digabungkan bernilai True. Dalam program, and digunakan untuk menentukan apakah member yang memenuhi minimum belanja mendapatkan diskon. Operator or menghasilkan True apabila minimal salah satu kondisi bernilai True, misalnya ketika memeriksa syarat promo. Operator not digunakan untuk membalik nilai Boolean, contohnya not status_member_3003 menghasilkan True ketika pelanggan bukan member.
#
# 3. Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.
#
# Operator in digunakan untuk memeriksa apakah suatu kode promo terdapat di dalam daftar promo yang tersedia. Jika kode ditemukan, hasilnya True. Sebaliknya, not in digunakan untuk memeriksa apakah kode promo tidak terdapat dalam daftar. Contohnya, HEMAT10 in daftar_promo_3003 menghasilkan True.
#
# 4. Apa perbedaan antara is dan == pada Python?
#
# == digunakan untuk membandingkan nilai atau isi dari dua objek, sedangkan is digunakan untuk membandingkan identitas objek, yaitu apakah dua variabel menunjuk pada objek yang sama. Pada program, dua list dapat mempunyai isi yang sama sehingga == bernilai True, tetapi tetap merupakan objek yang berbeda sehingga is bernilai False.
#
# 5. Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.
#
# Setiap kondisi pelanggan direpresentasikan dengan satu bit. 0001 menunjukkan member, 0010 menunjukkan belanja minimal Rp200.000, 0100 menunjukkan jumlah barang minimal 3, dan 1000 menunjukkan kode promo tersedia. Operator OR (|) digunakan untuk menggabungkan kondisi tersebut menjadi satu kode status. Operator AND (&) digunakan untuk memeriksa bit tertentu sehingga hak akses pelanggan dapat diketahui. Operator XOR (^) digunakan untuk membandingkan kode transaksi dengan kode referensi.
#
# 6. Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.
#
# Program dimulai dengan meminta nama, status pelanggan, total belanja, jumlah barang, dan kode promo. Data tersebut kemudian digunakan untuk melakukan perbandingan terhadap syarat minimum belanja, jumlah barang, status member, dan ketersediaan promo. Kondisi-kondisi tersebut digabungkan menggunakan operator logika untuk menentukan diskon dan promo. Setelah itu program menghitung besar diskon, total pembayaran, rata-rata harga barang, dan poin pelanggan. Selanjutnya kondisi pelanggan diubah menjadi kode bitwise untuk menentukan hak akses dan menampilkan hasil seluruh operator.
#
# 7. Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.
#
# Contoh kondisi True adalah:
#
# total_belanja_3003 >= 200000
#
# jika total belanja Rp250.000, hasilnya True.
#
# Contoh kondisi False adalah:
#
# jumlah_barang_3003 >= 3
#
# jika pelanggan membeli 2 barang, hasilnya False.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum Algoritma dan Pemrograman Pekan 3, dapat disimpulkan bahwa operator merupakan bagian penting dalam pembuatan program Python. Berbagai jenis operator memiliki fungsi yang berbeda, mulai dari melakukan perhitungan menggunakan operator aritmatika, memberikan dan memperbarui nilai menggunakan assignment, membandingkan kondisi menggunakan operator perbandingan, hingga menggabungkan kondisi menggunakan operator logika.
#
# Selain itu, operator membership dapat digunakan untuk memeriksa keberadaan suatu nilai dalam koleksi data, sedangkan operator identity digunakan untuk membandingkan identitas objek. Operator bitwise dapat digunakan untuk melakukan pengolahan data dalam bentuk biner dan dapat diterapkan untuk merepresentasikan beberapa kondisi dalam satu kode status.
#
# Melalui studi kasus sistem simulasi transaksi dan validasi akses toko, berbagai operator tersebut dapat diterapkan secara terintegrasi dalam satu program. Program dapat menerima data dari pengguna, melakukan perhitungan transaksi, menentukan status diskon dan promo, serta menentukan hak akses pelanggan berdasarkan kondisi yang telah ditentukan.
#
# Dengan demikian, praktikum ini membantu meningkatkan pemahaman mengenai fungsi dan penerapan berbagai operator Python serta kemampuan untuk menggunakannya dalam menyelesaikan suatu permasalahan secara terstruktur.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “Built-in Types,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/library/stdtypes.html [Diakses 17 September 2026].
#
# [2] Python Software Foundation, “Expressions — Python 3 Documentation,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html [Diakses 17 September 2026].
#
# [3] Python Software Foundation, “More Control Flow Tools,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/tutorial/controlflow.html [Diakses 17 September 2026].
